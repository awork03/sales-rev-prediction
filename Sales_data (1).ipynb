# %%
import pandas as pd
import numpy as np
data = {
    "name": ["Alice", "Ben", "Carlos", "Dana", "Elena", "Frank", "Grace", "Henry", "Isabella", "Jake"],
    "years_experience": [2, 5, 1, 4, 3, 6, 2, 7, 3, 5],
    "deals_closed": [12, 20, 8, 16, 14, 24, 10, 26, 13, 19],
    "total_sales": [120000, 210000, 75000, 190000, 160000, 260000, 110000, 280000, 140000, 200000],
    "region": ["East", "West", "South", "North", "West", "East", "South", "North", "East", "South"],
    "product_knowledge": [7.5, 9.0, 6.0, 8.5, 8.0, 9.5, 9.8, 7.8, 8.7, np.nan], # Added np.nan to make the list length 10
    "client_satisfaction": [4.2, 4.8, 3.5, 4.6, 4.3, 4.9, 4.0, 4.7, 4.1, 4.5],
    "calls_made": [250, 320, 180, 300, 270, 350, 240, 360, 260, 310],
    "revenue": [25000, 48000, 15000, 42000, 36000, 55000, 22000, 58000, 32000, 44000]
             }

df = pd.DataFrame(data)

df = pd.get_dummies(df, columns=['region'])

print(df.head())
# Out:
#      name  years_experience  deals_closed  total_sales  product_knowledge  \
# 0   Alice                 2            12       120000                7.5
# 1     Ben                 5            20       210000                9.0
# 2  Carlos                 1             8        75000                6.0
# 3    Dana                 4            16       190000                8.5
# 4   Elena                 3            14       160000                8.0
#
#    client_satisfaction  calls_made  revenue  region_East  region_North  \
# 0                  4.2         250    25000         True         False
# 1                  4.8         320    48000        False         False
# 2                  3.5         180    15000        False         False
# 3                  4.6         300    42000        False          True
# 4                  4.3         270    36000        False         False
#
#    region_South  region_West
# 0         False        False
# 1         False         True
# ...

# %%
import pandas as pd

df = pd.read_csv('data.csv')

print(df.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-15-2727192674.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv('data.csv')
#       4
#       5 print(df.head())
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a scatter plot
plt.figure(figsize=(8, 6))
sns.scatterplot(x='deals_closed', y='total_sales', data=df)
plt.title('Relationship between Deals Closed and Total Sales')
plt.xlabel('Deals Closed')
plt.ylabel('Total Sales ($)')
plt.grid(True)
plt.show()

# %%
# @title
# Sort by Revenue Generated
print("Top salesmen by Revenue Generated:")
display(df.sort_values(by='revenue', ascending=False)[['name', 'revenue']].head())

# Sort by Deals Closed
print("\nTop salesmen by Deals Closed:")
display(df.sort_values(by='deals_closed', ascending=False)[['name', 'deals_closed']].head())

# Sort by Client Satisfaction
print("\nTop salesmen by Client Satisfaction:")
display(df.sort_values(by='client_satisfaction', ascending=False)[['name', 'client_satisfaction']].head())
# Out:
# Top salesmen by Revenue Generated:
#     name  revenue
# 7  Henry    58000
# 5  Frank    55000
# 1    Ben    48000
# 9   Jake    44000
# 3   Dana    42000
# Top salesmen by Deals Closed:
#     name  deals_closed
# 7  Henry            26
# 5  Frank            24
# 1    Ben            20
# 9   Jake            19
# 3   Dana            16
# Top salesmen by Client Satisfaction:
#     name  client_satisfaction
# 5  Frank                  4.9
# 1    Ben                  4.8
# 7  Henry                  4.7
# 3   Dana                  4.6
# 9   Jake                  4.5
